# %% [markdown]
# ## Topics: String Functions, Type Casting, Input, Operators, and If-Else (Nested)

# %% [markdown]
# ### 1. Ek string variable banayein jisme aapka full name ho, aur usse poora CAPITAL letters mein print karein.

# %%
name = "Nisar Hussain"
print(name.upper())
# Out:
# NISAR HUSSAIN

# %% [markdown]
# ### 2. User se unka fav fruit poochiye aur uski length (kitne characters hain) print karein.

# %%
# Write your code here
fruit = input("mango: ")
print("lenth:",len(fruit))
# Out:
# mango:  mango
# lenth: 5

# %% [markdown]
# ### 3. Ek sentence likhiye 'Python is fun' aur 'fun' ko 'awesome' se replace karke print karein.

# %%
# Write your code here
sentence = "python is fun"''
new_sentence = sentence.replace("fun","awesome")
print(new_sentence)
# Out:
# python is awesome

# %% [markdown]
# ### 4. Check karein ke string 'Hello World' mein 'World' kaunse index par start hota hai.

# %%
# Write your code here
text = "hello world"
index = text.find("world")
print (index)
# Out:
# 6

# %% [markdown]
# ### 5. User se unka email address lein aur usse hamesha small letters (lowercase) mein convert karke dikhayein.

# %%
# Write your code here
email = input("vinod@gmail.com: ")
print(email.lower())
# Out:
# vinod@gmail.com:  vinod@gmail.com
# vinod@gmail.com

# %% [markdown]
# ### 6. Ek sentence '   Python Programming   ' banayein aur uske extra spaces (suru aur aakhir ke) remove karein.

# %%
# Write your code here
sentence = 'python programing'
print(sentence.strip())

# %% [markdown]
# ### 7. Ek string 'Welcome to coding' mein count karein ke 'o' letter kitni baar aaya hai.

# %%
# Write your code here
text = "welcome to coding"
print(text.count('o'))
# Out:
# 3

# %% [markdown]
# ### 8. User se unki age input lein aur usse integer mein convert karke print karein.

# %%
# Write your code here 
age = 35
age = int(input("age"))
print(age)
# Out:
# age 15
# 15

# %% [markdown]
# ### 9. Ek float value '15.99' ko integer mein convert karein. Output kya aaya?

# %%
# Write your code here
num =15.99
print(int(num))
# Out:
# 15

# %% [markdown]
# ### 10. Do numbers ko input lein, dono ko add karein, lekin dhayan rahe input hamesha string hota hai, isliye unhe cast karein.

# %%
# Write your code here
num1 = 10 
num2 = 15
print(num1 + num2)
# Out:
# 25

# %% [markdown]
# ### 11. Ek integer 100 ko string mein convert karein aur check karein ke uska type ab 'str' hai ya nahi.

# %%
# Write your code here
num = 100
num_str = str
print(type(num))
# Out:
# <class 'int'>

# %% [markdown]
# ### 12. User se price lein (e.g., 99.5) aur usse integer mein badal kar dikhayein.

# %%
# Write your code here
price = 99.5
price = float(input("price"))
price_int = int(price)
print(price_int)
# Out:
# price 99.5
# 99

# %% [markdown]
# ### 13. Ek string '10' aur doosri string '20' ko add (concatenate) karne ki jagah math wala addition (30) karke dikhayein.

# %%
# Write your code here
a = "10"
b = "20"
10+20
# Out:
# 30

# %% [markdown]
# ### 14. Ek variable mein '50.5' save karein aur usse float mein cast karne ke baad 10 plus karein.

# %%
# Write your code here
value = "50.5"
num = float(value)
result = num + 10 
print(result)
# Out:
# 60.5

# %% [markdown]
# ### 15. User se uska naam aur shehar (city) ka naam poochiye aur ek sentence print karein: 'Hello [Name], welcome to [City]'.

# %%
# Write your code here 
name = input("name : ")
city = input("city : ")
print('Hello[vinod],welcome to [karachi]')
# Out:
# name :  vinod
# city :  karachi
# Hello[vinod],welcome to [karachi]

# %% [markdown]
# ### 16. User se do numbers lein aur unka product (multiply) print karein.

# %%
# Write your code here
num1 = 34
num2 = 65
(34*65)
# Out:
# 2210

# %% [markdown]
# ### 17. User se unka favorite color poochiye aur print karein: 'I also like [color]'.

# %%
# Write your code here
color = input("color: ")
print("I also like",color)
# Out:
# color:  red
# I also like red

# %% [markdown]
# ### 18. Ek chota program banayein jo user se uska birth year le aur uska current age calculate karein.

# %%
# Write your code here
brith_year = int(input("brith_year: "))
current_year = 2026
age = current_year - brith_year
print("your age is:",age)
# Out:
# brith_year:  2007
# your age is: 19

# %% [markdown]
# ### 19. User se ek word input lein aur usse 5 baar print karein (string multiplication use karke).

# %%
# Write your code here
word = input("word: ")
print(word*5)
# Out:
# word:  hello
# hellohellohellohellohello

# %% [markdown]
# ### 20. User se unka mobile number lein (as string) aur unhe batayein ke unhone kya number type kiya hai.

# %%
# Write your code here
number = str(input("number: "))
print("you entered:", number)
# Out:
# number:  03308350680
# you entered: 03308350680

# %% [markdown]
# ### 21. Do variables lein a=10, b=3. Inka remainder (modulo) nikal kar dikhayein.

# %%
# Write your code here
a = 10 
b = 3
print(a%b)
# Out:
# 1

# %% [markdown]
# ### 22. Check karein ke 15, 10 se bada hai AUR 20 se chota hai (Logical AND operator).

# %%
# Write your code here
a = 15
b = 10 
c = 20
print(15>10<20)
# Out:
# True

# %% [markdown]
# ### 23. User se ek number lein aur check karein ke wo 100 se bada hai ya nahi (Comparison operator).

# %%
# Write your code here
a = 75
b= 100
print(75>100)
# Out:
# False

# %% [markdown]
# ### 24. 2 ki power 5 (2^5) calculate karke print karein.

# %%
(2^5)
# Out:
# 7

# %% [markdown]
# ### 25. Check karein ke kya 50, 100 ke barabar hai (Equal to operator).

# %%
# Write your code here
50==100
# Out:
# False

# %% [markdown]
# ### 26. Do Boolean values (True, False) lein aur 'OR' operator ka result dikhayein.

# %%
# Write your code here
a = True 
b = False
print(a or b)
# Out:
# True

# %% [markdown]
# ### 27. User se ek number lein aur check karein ke wo Positive hai ya Negative.

# %%
# Write your code here
num = int(input("Enter a number: "))
if num>=0:
    print("positive")
elif num<=0:
    print("negative")
else:
    print("0")
# Out:
# Enter a number:  4
# positive

# %% [markdown]
# ### 28. Check karein ke user ki age 18 se zyada hai ya nahi, agar hai toh print 'Eligible for Vote'.

# %%
# Write your code here
age =int(input("Enter your age: "))
if age>=18:
    print("Eligible for vote")
else:
    print("not eligible for vote")
# Out:
# Enter your age:  19
# Eligible for vote

# %% [markdown]
# ### 29. Ek number input lein aur check karein ke wo Even hai ya Odd.

# %%
# Write your code here
num =int(input("Enter your number"))
if num % 2==0:
    print("Even")
else:
    print("odd")
# Out:
# Enter your number 7
# odd

# %% [markdown]
# ### 30. User se do numbers lein aur batayein dono mein se bada (Greater) kaunsa hai.

# %%
# Write your code here
num1 = 18
num2 = 78
print(num1 > num2)
# Out:
# False

# %% [markdown]
# ### 31. Ek student ke marks input lein. Agar marks 33 se zyada hain toh 'Pass', warna 'Fail'.

# %%
# Write your code here46

student =int(input("marks"))
if student>33:
    result = "Pass"
else:
    result="Fail"
print(result)
# Out:
# marks 56
# Pass

# %% [markdown]
# ### 32. Check karein ke user ne jo string input ki hai wo empty toh nahi hai.

# %%
# Write your code here
text =input("")
if text =="":
    print("string is empty")
else:
    print("string is not empty")
# Out:
#  2
# string is not empty

# %% [markdown]
# ### 33. User se ek password input lein. Agar password 'python123' hai toh 'Access Granted', warna 'Wrong Password'.

# %%
# Write your code here
password = input("Enter pasword")
if password =="python123":
    print("Access Granted")
else:
    print("Access not Granted")
# Out:
# Enter pasword python123
# Access Granted

# %% [markdown]
# ### 34. Check karein ke user ka input kiya hua number zero hai ya nahi.

# %%
# Write your code here
num = input("Enter a number: ")
if num == 0:
    print("number is zero")
else:
    print("number is not zero")
# Out:
# Enter a number:  7
# number is not zero

# %% [markdown]
# ### 35. Student Grading System: 90+ (A), 80-89 (B), 70-79 (C), below 70 (D).

# %%
# Write your code here
mark =int(input("Enter a marks: "))
if mark>=90:
    print('Grade A')
elif mark == 80-89:
    print('Grade B')
elif mark == 70-79:
    print('Grade C')
else:
    print("Grade D")
# Out:
# Enter a marks:  76
# Grade D

# %% [markdown]
# ### 36. User se temperature lein. Agar 30 se zyada hai toh 'Hot', 15-30 hai toh 'Warm', 15 se niche hai toh 'Cold'.

# %%
# Write your code here
temp = float(input("what is the temperature today? "))
if temp>=30:
    print("today is hot day")
elif temp>=15-30:
    print("today is warm day")
elif temp>=15:
    print("today is cold day")
else:
    print("today is hot day")
# Out:
# what is the temperature today?  34
# today is hot day

# %% [markdown]
# ### 37. Ek number check karein ke wo 3 se divisible hai, 5 se divisible hai, ya dono se (FizzBuzz logic).

# %%
# Write your code here 
num =int(input("Enter a number: "))
if num % 3 == 0 and num % 5 == 0:
    print("FizzBuzz")
elif num % 3 == 0:
    print("Fizz")
elif num % 5 == 0:
    print("Buzz")
else:
    print("Not divisible by 3 or 5")
# Out:
# Enter a number:  5
# Buzz

# %% [markdown]
# ### 38. User se ek character lein aur check karein ke wo Vowel (a, e, i, o, u) hai ya Consonant.

# %%
# Write your code here
character =input("Enter a character: ")
if character in ('a','e','i','o','u',
                
                'A','E','I','O','U'):
    print("vowel")
else:
    print("consonant")
# Out:
# Enter a character:  e
# vowel

# %% [markdown]
# ### 39. Bill Calculator: Agar shopping 5000 se upar hai toh 20% discount, 2000-5000 par 10% discount, warna No discount.

# %%
# Write your code here
shopping = float(input("Enter shopping amount: "))
if shopping >5000:
             discount = shopping*0.20
             final_bill = shopping - discount
             print("20% Discount")
             print("Final Bill =", final_bill)
elif shopping >=2000:
         discount = shopping * 0.10
         final_bill = shopping - discount
         print("10% Discount")
         print("Final Bill =", final_bill)
else:
     print("No Discount")
     print("Final bill =",shopping)
# Out:
# Enter shopping amount:  5400
# 20% Discount
# Final Bill = 4320.0

# %% [markdown]
# ### 40. Ek person ki age check karein: 0-12 (Child), 13-19 (Teenager), 20-59 (Adult), 60+ (Senior Citizen).

# %%
# Write your code here
age = int(input("Enter your age: "))
if age >= 0 and age <=12:
    print("Child")
elif age>= 13 and age <=19:
    print("Teenager")
elif age>= 20 and age <=59:
    print("Adult")
else:
    print("Senior citizen")
# Out:
# Enter your age:  34
# Adult

# %% [markdown]
# ### 41. Check karein ke ek saal (year) Leap Year hai ya nahi.

# %%
# Write your code here
year = int(input("Enter a year: "))
if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("Leap year")
else:
    print("Not leap year")
# Out:
# Enter a year:  5
# Not leap year

# %% [markdown]
# ### 42. User se week number (1-7) lein aur corresponding day (Monday, Tuesday...) print karein.

# %%
# Write your code here 
week =int(input("Enter week number (1-7): "))
if week == 1:
    print("Monday")
elif week == 2:
    print("Tuesday")
elif week == 3:
    print("Wedensday")
elif week == 4:
    print("Thursday")
elif week == 5:
    print("Friday")
elif week == 6:
    print("seturday")
elif week == 7:
    print("Sunday")
else:
    print("Invaild week number")
# Out:
# Enter week number (1-7):  5
# Friday

# %% [markdown]
# ### 43. Ek simple calculator banayein (+, -, *, /) symbols ke basis par operation perform karein.

# %%
# write your code here 
num1 = float(input("Enter frist number: "))
num2 = float(input("Enter second number: "))
operater = input("Enter operater (=, -, *, /): ")
if operater == "+":
    print("Answer =", num1 + num2)
elif operater == "-":
    print("Answer =", num1 - num2)
elif operater =="*":
    print("Answer =", num1 * num2)
elif operater =="/":
    print("Answer =", num1 / num2)
else:
    print("invaild operater")
# Out:
# Enter frist number:  6
# Enter second number:  3
# Enter operater (=, -, *, /):  +
# Answer = 9.0

# %% [markdown]
# ### 44. User ka weight aur height le kar BMI category batayein (Underweight, Normal, Overweight).

# %%
# Write your code here
weight = float(input("enter weight in kg: "))
height = float(input("Enter height in meter: "))
bmi = weight /(height**2)
print("BMI=",bmi)
if weight <  18.5:
    print("underwaight")
elif weight >= 18.5 and bmi <= 25:
    print("normal")
else:
    print("overwaight")
# Out:
# enter weight in kg:  60
# Enter height in meter:  1.7
# BMI= 20.761245674740486
# normal

# %% [markdown]
# ### 45. ATM Machine Logic: Pehle PIN check karein, agar sahi ho toh Amount poochiye, agar account balance se kam amount ho toh 'Withdrawal Success'.

# %%
# Write your code here
pin = 1234
balance = 10000
user_pin = int(input("Enter pin: "))
if user_pin == pin:
    amount = float(input("Enter withdrawel amount: "))
    if amount <= balance:
        print("withdrawel success")
    else:
        print("insufficient balance")

else:
    print("incorrect pin")
# Out:
# Enter pin:  1234
# Enter withdrawel amount:  7000
# withdrawel success

# %% [markdown]
# ### 46. Login System: Pehle Username check karein, agar match ho tabhi Password check karein.

# %%
# Write your code here
correct_username = "raj"
correct_password = "9988"
username = input("Enter")
if username ==  correct_username:
    password= input("Enter password: ")
    if password == correct_password:
        print("login successful")
    else:
        print("wrong password")
else:
    print("wrong username")
# Out:
# Enter raj
# Enter password:  9988
# login successful

# %% [markdown]
# ### 47. Largest of Three: User se 3 numbers lein aur nested if-else use karke sabse bada number dhoondein.

# %%
# Write your code here
num1 = float(input("Enter frist number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))
if num1> num2:
    if num1 > num3:
        print("Largest number is:", num1)
    else:
        print("Largest number is:", num3)
else:
    if num2>num3:
        print("Largest number is:",num2)
    else:
        print("Largest number is:", num3)
# Out:
# Enter frist number:  23
# Enter second number:  45
# Enter third number:  2
# Largest number is: 45.0

# %% [markdown]
# ### 48. Ticket Booking: Pehle age check karein. Agar 18+ hai toh check karein 'Do you have ID?'. Agar ID hai toh 'Ticket Issued'.

# %% [markdown]
#  Write your code here
# age = int(input("Enter your age :"))
# if age >= 18:
#     id_card = input("Do you have ID?(yea/no): ")
#     if id_card == "yes":
#         print("Ticket Issued")
#     else:
#         print("ID Required")
# else:
#     print("you are underage ")

# %%
# write your code here 
age = int(input("Enter your age: "))
if age >= 18:
    id_card = input("Do you have ID?(yes/no): ")
    if id_card == "yes":
        print("Ticket Issued")
    else: 
        print("ID Required")
else:
    print("you are underage")
# Out:
# Enter your age:  25
# Do you have ID?(yes/no):  no
# ID Required

# %% [markdown]
# # 49. Admission System: Agar student ke marks 80+ hain, toh check karein unka interview clear hai ya nahi. Dono clear hone par 'Admission Done'.

# %%
# Write your code here
marks = int(input("Enter your marks: "))
if marks >= 80:
    interview = input("Interview Cleared? (yes/no): ")
    if interview == "yes":
        print("Admission done")
    else:
        print("Interview Not Cleared")
else:
    print("marks are less than interview")
# Out:
# Enter your marks:  89
# Interview Cleared? (yes/no):  yes
# Admission done

# %% [markdown]
# ### 50. Number Range: Check karein number positive hai ya nahi. Agar positive hai, toh check karein wo 100 se bada hai ya chota.

# %%
# Write your code here
num = int(input("Enter a number: "))
if num> 0:
    if num > 100:
        print("Number is greater than 100")
    else:
        print("Number is less than equal to 100")
else:
    print("Number is not positive")
# Out:
# Enter a number:  -4
# Number is not positive

# %% [markdown]
# ### 51. Restaurant Order: Pehle Veg ya Non-Veg poochein. Veg mein Paneer ya Dal, Non-Veg mein Chicken ya Mutton ka option dein.

# %%
# Write your code here
choice = input("Enter veg or non_veg: ")
if choice == "veg":
    item = input("choose Paneer or Dal: ")
    if item == "Paneer":
        print("Paneer selected")
    else:
        print("Dal selected")
else:
    item = input("choose Chicken or muttan: ")

    if item == "Chicken":
        print("Chicken selected")
    else:
        print("Muttan selected")
# Out:
# Enter veg or non_veg:  Paneer
# choose Chicken or muttan:  Chicken
# Chicken selected

# %% [markdown]
# ### 52. Ek number input lein aur check karein ke wo Single digit hai, Double digit ya Triple digit.

# %%
# Write your code here
num = int(input("Enter a number: "))
num = abs (num)
if num >= 0 and num <= 9:
    print("single digit")
elif num >= 10 and num <= 99:
    print("Double digit")
elif num >= 100 and num <= 999:
    print("Triple digit")
else:
    print(" More than triple digit")
# Out:
# Enter a number:  56
# Double digit

# %% [markdown]
# ### 53. User se salary aur service years lein. Agar service 5 saal se zyada hai toh 5% bonus calculate karke final salary batayein.

# %%
# Write your code here
salary = float(input("Enter salary: "))
years = int(input("Enter service years: "))
if years > 5:
    bonus = salary*0.05
    final_salary = salary + bonus
    print("Bonus =", bonus)
    print("Final_salary =", final_salary)
else:
    print("No bonus")
    print("Final salary =", salary)
# Out:
# Enter salary:  50000
# Enter service years:  6
# Bonus = 2500.0
# Final_salary = 52500.0

# %% [markdown]
# ### 54. Ek triangle ki teen sides input lein aur batayein ke wo Equilateral, Isosceles ya Scalene hai.

# %% [markdown]
# #### Write your code here
# side1 =float(input("Enter frist side: "))
# side2 =float(input("Enter second side: "))
# side3 =float(input("enter third side: "))
# if side1 == side2 and side2 == side3:
#     print("Equuilateral Triangle")
# elif side1 == side2 or side2 == side3 or side2 ==  side3:
#     print("Isosceles Trinangle")
# else:
#     print("Scalene Trinagngle")

# %%
# write your code here
side1 =float(input("Enter frist number: "))
side2 = float(input("Enter second number: "))
side3 = float(input("Enter thrid number: "))
if side1 == side2 and side2 == side3:
    print("Equilateral Triangle")
elif side1 == side2 or side1 == side3 or side2 == side3:
    print("Isosceles Triangle")
else:
    print("Scelene Triangle")
# Out:
# Enter frist number:  2
# Enter second number:  1
# Enter thrid number:  3
# Scelene Triangle

# %% [markdown]
# ### 55. Month name check karke batayein ke us month mein kitne days hote hain (Jan, Feb...).

# %%
# Write your code here
month =input("Enter month name: ")
if month == "january":
    print("31 days")
elif month == "February":
    print("28 or 29 days")
elif month == "March":
    print("31 days")
elif month == "April":
    print("30 days")
elif month == "May":
    print("31 days")
elif month == "June":
    print("30 days")
elif month == "July":
    print("31 days")
elif month == "August":
    print("31 days")
elif month == "September":
    print("30 days")
elif month == "October":
    print("31 days")
elif month == "November":
    print("30 days")
elif month == "December":
    print("31 days")
else:
    print("invailed month")
# Out:
# Enter month name:  january
# 31 days

# %% [markdown]
# ### 56. Nested If-Else se check karein ke ek number Even hai aur 50 se bada hai, ya Even hai aur 50 se chota hai.

# %%
# Write your code here
num = int(input("Enter a number: "))
if num % 2 ==0:
    if num > 50:
        print("Number is Even and greater than 50")
    else:
        print("Number is Even and less than 50")
else:
    print("Number is odd")
# Out:
# Enter a number:  67
# Number is odd

# %% [markdown]
# ### 57. Student Result: Maths aur Science dono mein 40+ hone chahiye pass hone ke liye. Agar ek mein kam hain toh batayein kaunsa subject weak hai.

# %%
# Write your code here
maths = int(input("Enter math marks: "))
science = int(input("Enter science marks: "))
if maths >= 40 and science >= 40:
    print("Pass")
else:
    if maths < 40:
        print("math is weak")
    if science < 40:
        print("science weak")
# Out:
# Enter math marks:  55
# Enter science marks:  34
# science weak

# %% [markdown]
# ### 58. Electricity Bill: Pehle 100 units free, next 100 units Rs 5/unit, uske baad Rs 10/unit.

# %%
# Write your code here
units = int (input("Enter electricity units: "))
if units <=100:
    bill =  0
elif units <=200:
    bill = ( units - bill) * 5
else:
    bill = (100 * 5) + ((units - 200) * 10)
    print("Electricity Bill =", bill)
# Out:
# Enter electricity units:  500
# Electricity Bill = 3500

# %% [markdown]
# ### 59. Game Level: Score 0-50 (Beginner), 51-100 (Intermediate). Agar Intermediate hai toh check karein user ne boss level par kiya hai ya nahi.

# %%
# Write your code here
score = int(input("Enter your score: "))
if 0 <=score <= 50:
    print("Beginner level")
elif 50 <= score <=100:
    print("Intermediae level")
    boss = input("Boss level comleted? (yes/no): ")
    if boss=="yes":
        print("boss levl cleared")
    else:
        print("boss level not cleared")
else:
    print("Advance level")
# Out:
# Enter your score:  56
# Intermediae level
# Boss level comleted? (yes/no):  no
# boss level not cleared

# %% [markdown]
# ### 60. Final Challenge: Ek mini-project logic banayein jisme user se Username, Password, aur ek Security Question poochein nested loops aur if-else ke saath.

# %%
# Write your code here
#stored data 
correct_username = "amit"
corrct_password = "4455"
security_answer = "vinod"
# login attempts
for i in range(3):
    username = input("Enter username: ")
    password = input("Enter password: ")
    if username == correct_username:
        if password == correct_password:
            print("Login Successful")
            break
        else:
            print("Wrong password")
            answer = input("Security Question - What is your favorite color? ")
            if answer == security_answer:
                new_password = input("Enter new password:: ")
                correct_password = new_password
                print("password reset successful")
            else:
                print("security answer incorrect")
    else:
        print("Wrong username ")
else:
    print("Account Blocked after 3 attemts")
# Out:
# Enter username:  vinood
# Enter password:  234
# Wrong username
# Enter username:  amit
# Enter password:  4455
# Wrong password
# Security Question - What is your favorite color?  vinod
# Enter new password::  4455
# password reset successful
# Enter username:  amit
